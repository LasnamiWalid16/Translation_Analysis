# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data=pd.read_csv('traductions.csv',sep=',')

# %%
data.head(10)
# Out:
#    546     REBAHI     AMINE  0558500659  701  2021-10-02 14:14:38   25  \
# 0  547  BOUCHAFAA      AMAR   770130202  702  2021-10-02 14:26:58   40
# 1  543    DEGHOUL   MOHAMED   542764940  697  2021-10-02 15:46:12  107
# 2  544    MAHDADI     ZHOUR   550478415  698  2021-10-03 13:14:34   28
# 3  545       DINE     AHMED   554780334  700  2021-10-03 14:09:26    1
# 4  555   CHERIGUI    MOUNIR   550262263  709  2021-10-04 07:30:00    4
# 5  548     SEHILI      AMEL   555369007  703  2021-10-04 08:28:45   22
# 6  548     SEHILI      AMEL   555369007  703  2021-10-04 08:28:45    4
# 7  556       0809   slimane   774701881  710  2021-10-05 07:33:28    1
# 8  554      AHMED  BENYAHIA   776186142  712  2021-10-05 07:39:30    4
# 9  554      AHMED  BENYAHIA   776186142  712  2021-10-05 07:39:30    5
#
#         Certificat Médical  1200  fr->arb  1
# 0     Registre de Commerce  5000  arb->fr  1
# 1       CONTRAT DE TRAVAIL  1400  fr->arb  4
# 2    Certificat De Travail  1000  arb->fr  1
# 3   attestation de travail  1500  arb->fr  1
# 4          Relevé de notes  1500  arb->fr  2
# 5  CERTIFICAT DE SCOLARITÉ  1500  fr->arb  1
# 6          Relevé de notes  1500  fr->arb  1
# 7   attestation de travail  1500  arb->fr  1
# 8          Relevé de notes  5000  arb->fr  1
# 9              Diplome BAC  1500  arb->fr  1

# %%
data.shape
# Out:
# (1002, 11)

# %% [markdown]
# We notice that we have 675 line and 11 columns

# %%
data.describe()
# Out:
#          client_id     telephone  traduction_id  id_document          prix  \
# count   675.000000  6.750000e+02     675.000000   675.000000    675.000000
# mean    784.354074  6.159748e+08     990.880000    28.771852   1609.111111
# std     137.798461  4.014811e+08     165.497081    29.975630   1122.825275
# min     543.000000  0.000000e+00     697.000000     1.000000    200.000000
# 25%     670.500000  5.514109e+08     847.500000     7.000000   1200.000000
# 50%     782.000000  5.598923e+08     989.000000    20.000000   1500.000000
# 75%     905.500000  7.714361e+08    1134.500000    40.000000   1500.000000
# max    1025.000000  7.789849e+09    1274.000000   116.000000  20000.000000
#
#           nbcopie
# count  675.000000
# mean     3.068148
# std      5.420708
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      3.000000
# max     53.000000

# %%
y=data['langue']
y
# Out:
# 0       fr->arb
# 1       arb->fr
# 2       fr->arb
# 3       arb->fr
# 4       arb->fr
#          ...
# 670     fr->arb
# 671     fr->arb
# 672     fr->arb
# 673    arb->ang
# 674     fr->arb
# Name: langue, Length: 675, dtype: object

# %%
encoder=LabelEncoder()
encoder.fit_transform(y)
# Out:
# array([5, 3, 5, 3, 3, 3, 5, 5, 3, 3, 3, 3, 3, 1, 3, 2, 3, 3, 5, 5, 5, 5,
#        3, 4, 4, 4, 3, 5, 3, 5, 5, 3, 5, 3, 3, 5, 2, 5, 3, 5, 2, 3, 5, 3,
#        5, 5, 5, 5, 5, 3, 3, 5, 4, 5, 5, 2, 3, 3, 3, 3, 2, 2, 2, 3, 3, 2,
#        5, 5, 2, 2, 3, 3, 3, 5, 3, 3, 3, 5, 5, 5, 3, 3, 3, 5, 3, 3, 3, 5,
#        3, 3, 5, 3, 3, 3, 5, 5, 3, 5, 4, 1, 3, 5, 5, 2, 3, 5, 3, 3, 3, 5,
#        3, 3, 3, 5, 5, 5, 2, 2, 2, 5, 3, 5, 5, 5, 5, 5, 5, 5, 5, 5, 3, 3,
#        2, 3, 3, 4, 3, 5, 4, 5, 5, 5, 5, 4, 3, 2, 2, 2, 5, 5, 5, 3, 5, 5,
#        5, 5, 5, 3, 2, 4, 2, 2, 3, 3, 3, 2, 2, 3, 5, 5, 5, 3, 3, 1, 3, 3,
#        5, 5, 3, 5, 5, 4, 3, 5, 5, 3, 5, 5, 5, 2, 5])

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 670    False
# 671    False
# 672    False
# 673    False
# 674    False
# Length: 675, dtype: bool

# %%
DocGoup=data.groupby(data['document'])
DocGoup.head()
# Out:
#      client_id       name      prenom  telephone  traduction_id  \
# 0          546     REBAHI       AMINE  558500659            701
# 1          547  BOUCHAFAA        AMAR  770130202            702
# 2          543    DEGHOUL     MOHAMED  542764940            697
# 3          544    MAHDADI       ZHOUR  550478415            698
# 4          545       DINE       AHMED  554780334            700
# ..         ...        ...         ...        ...            ...
# 619        912   DJELMANI      KHALED  561005907           1226
# 622        996  KHELIFATI       AMINA  540619667           1229
# 627        999     ADDALA  ABDELMALEK  550234688           1234
# 634       1004     YACOUB      NADINE  697613912           1240
# 653       1014    MOKRANI     MOHAMED  771568388           1257
#
#               created_at  id_document                document  prix   langue  \
# 0    2021-10-02 14:14:38           25      Certificat Médical  1200  fr->arb
# 1    2021-10-02 14:26:58           40    Registre de Commerce  5000  arb->fr
# 2    2021-10-02 15:46:12          107      CONTRAT DE TRAVAIL  1400  fr->arb
# 3    2021-10-03 13:14:34           28   Certificat De Travail  1000  arb->fr
# 4    2021-10-03 14:09:26            1  attestation de travail  1500  arb->fr
# ..                   ...          ...                     ...   ...      ...
# 619  2022-02-06 15:11:26           26   Lettre Administrative  1000  fr->ang
# 622  2022-02-07 08:57:24           84         DOSSIER MEDICAL  1000  fr->ang
# 627  2022-02-08 13:54:47          115   DOSSIER ADMINISTRATIF  1500  fr->ang
# 634  2022-02-09 16:09:25           19             Procuration  1500  fr->arb
# 653  2022-02-14 10:48:27           70         fiche familiale  2000  fr->arb
#
#      nbcopie
# 0          1
# 1          1
# 2          4
# 3          1
# 4          1
# ..       ...
# 619        2
# 622        9
# 627        6
# 634        1
# 653        1
#
# [210 rows x 11 columns]
